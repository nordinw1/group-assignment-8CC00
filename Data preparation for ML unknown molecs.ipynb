# %% [markdown]
# <h1>Data preprocessing</h1>

# %% [markdown]
# <h2>Importing necessary modules</h2>

# %%
import csv
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
IPythonConsole.ipython_useSVG=True
from rdkit.Chem import Descriptors

# %%
# Define filepath to Molecules_combined.csv.
path = r"untested_molecules.csv"
csv_file = open(path, 'r')
reader = csv.reader(csv_file)
data = [row for row in reader]

# %% [markdown]
# <h2>Create DataFrame containing molecules and descriptors</h2>
# <p>Possible to export it as csv file.</p>

# %%
# TODO: more sensible variable names?
m = Chem.MolFromSmiles(data[1][0])
vs = Descriptors.CalcMolDescriptors(m)

df_full = pd.DataFrame(vs.items())
df_full.rename(columns={1:data[1][0]},inplace=True)

for i,x in enumerate(data[2:]):
    m = Chem.MolFromSmiles(x[0])
    vs = Descriptors.CalcMolDescriptors(m)
    df_full[x[0]] = vs.values()

df_full.to_csv('descriptors_unknown_molecs.csv')
# Out:
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()
# C:\Users\20202181\AppData\Local\Temp\ipykernel_27236\1952739764.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_full[x[0]] = vs.values()

# %% [markdown]
# <p>DataFrame has to be read in from previous save, as rest of the program bugs out otherwise :(</p>

# %%
df_full = pd.read_csv("descriptors_unknown_molecs.csv")
df_full.tail()
# Out:
#      Unnamed: 0                 0  \
# 204         204       fr_thiazole
# 205         205       fr_thiocyan
# 206         206      fr_thiophene
# 207         207  fr_unbrch_alkane
# 208         208           fr_urea
#
#      CCCCC/C(=N\NC(=O)CCC(=O)NCc1ccccc1)c1ccccc1  \
# 204                                          0.0
# 205                                          0.0
# 206                                          0.0
# 207                                          1.0
# 208                                          0.0
#
#      Cc1ccc(S(=O)(=O)N2CCC(C(=O)OCC(=O)N3CCc4ccccc43)CC2)cc1  \
# 204                                                0.0
# 205                                                0.0
# 206                                                0.0
# 207                                                0.0
# 208                                                0.0
#
#      COc1ccc(N2C(=O)CC(Nc3ccc(F)cc3)C2=O)c([N+](=O)[O-])c1  \
# 204                                                0.0
# 205                                                0.0
# 206                                                0.0
# 207                                                0.0
# 208                                                0.0
#
#      Cc1cc(C)cc(OCC(=O)O[NH+]=C(N)Cc2ccc([N+](=O)[O-])cc2)c1  \
# 204                                                0.0
# 205                                                0.0
# 206                                                0.0
# 207                                                0.0
# 208                                                0.0
#
#      NNC(=O)C=C1CCN(c2ncc(C(F)(F)F)cc2Cl)CC1  \
# 204                                      0.0
# 205                                      0.0
# 206                                      0.0
# 207                                      0.0
# 208                                      0.0
#
#      CC1(C)CC(=O)C2=C(C1)OC([NH3+])=C(C#N)[C@@]21C(=O)N(CC(N)=O)c2ccccc21  \
# 204                                                0.0
# 205                                                0.0
# 206                                                0.0
# 207                                                0.0
# 208                                                0.0
#
#      O=C(NCc1cccs1)C1CCC(CNS(=O)(=O)c2cccs2)CC1  \
# 204                                         0.0
# 205                                         0.0
# 206                                         2.0
# 207                                         0.0
# 208                                         0.0
#
#      O=C(c1ccc(S(=O)(=O)N2CCCCCC2)cc1)N1CCN(c2ccccn2)CC1  ...  \
# 204                                                0.0    ...
# 205                                                0.0    ...
# 206                                                0.0    ...
# 207                                                0.0    ...
# 208                                                0.0    ...
#
#      CC(C)CNC(=O)COC(=O)/C=C/c1ccccc1[N+](=O)[O-]  \
# 204                                           0.0
# 205                                           0.0
# 206                                           0.0
# 207                                           0.0
# 208                                           0.0
#
#      CCOC(=O)N1CCN(C(=O)c2cccc(OC)c2OC)CC1  COc1cccc(CNC2=[NH+]c3ccccc3CS2)c1  \
# 204                                    0.0                                0.0
# 205                                    0.0                                0.0
# 206                                    0.0                                0.0
# 207                                    0.0                                0.0
# 208                                    0.0                                0.0
#
#      COc1ccc(N2CC[NH+](CC(=O)Nc3c(C)cc(C)cc3C)CC2)cc1  \
# 204                                               0.0
# 205                                               0.0
# 206                                               0.0
# 207                                               0.0
# 208                                               0.0
#
#      CC(C)NC(=S)N/N=C1\CCCCC1C1CCCCC1  CCNC(=O)c1nc[nH]c1C(=O)NCC  \
# 204                               0.0                         0.0
# 205                               0.0                         0.0
# 206                               0.0                         0.0
# 207                               0.0                         0.0
# 208                               0.0                         0.0
#
#      CCC(C)C(NC(=O)C(C)NC(=O)CNC(=O)CNC(=O)OCc1ccccc1)C(=O)OC  \
# 204                                                0.0
# 205                                                0.0
# 206                                                0.0
# 207                                                0.0
# 208                                                0.0
#
#      O=C(CSc1ncnc2ccccc12)Nc1cccc(S(=O)(=O)N2CCOCC2)c1  \
# 204                                                0.0
# 205                                                0.0
# 206                                                0.0
# 207                                                0.0
# 208                                                0.0
#
#      Cc1cc(OCCOCC[NH+](C)CCO)cc(C)c1Cl  \
# 204                                0.0
# 205                                0.0
# 206                                0.0
# 207                                3.0
# 208                                0.0
#
#      CC(C)C(C(=O)NCc1ccco1)N(C(=O)CNS(=O)(=O)c1ccccc1)c1ccccc1
# 204                                                0.0
# 205                                                0.0
# 206                                                0.0
# 207                                                0.0
# 208                                                0.0
#
# [5 rows x 9971 columns]

# %% [markdown]
# <h2>Create DataFrame containing ALDH1 inhibition data for 2000 given molecules</h2>

# %%
df_inhibition = pd.read_csv("Molecules_combined.csv")
df_inhibition.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\20202181\OneDrive - TU Eindhoven\Documents\Vakken\Advanced Programming\group-assignment-8CC00\Data preparation for ML unknown molecs.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/20202181/OneDrive%20-%20TU%20Eindhoven/Documents/Vakken/Advanced%20Programming/group-assignment-8CC00/Data%20preparation%20for%20ML%20unknown%20molecs.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> df_inhibition = pd.read_csv("Molecules_combined.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/20202181/OneDrive%20-%20TU%20Eindhoven/Documents/Vakken/Advanced%20Programming/group-assignment-8CC00/Data%20preparation%20for%20ML%20unknown%20molecs.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> df_inhibition.tail()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# <h2>Combine feature data and label data</h2>
# <p>A row containing the ALDH1 inhibition for every molecule is added. If no inhibition data is available for a molecule, <br>that entry is deleted from the DataFrame.</p>

# %%
# Create list with all molecules reported in df_full, 
# leaving out the non-molecule names.
all_molecules = list(df_full.columns)
del all_molecules[:2]

# Create list with all molecules reported in df_inhibition.
select_molecules = list(df_inhibition["SMILES"])

# Create list to store molecules in which are not found in the bigger dataset, if any.
molecule_not_found = []

# Create new DataFrame, with similar shape to df_full though with 
# one extra row for the ALDH1 inhibition data.
df_combined = pd.DataFrame(np.zeros, index=pd.RangeIndex(len(df_full)+1), columns=df_full.columns)
df_combined.loc[np.arange(len(df_full))] = df_full.values

# Loop through the molecules in df_inhibition and check whether the molecules can be 
# found in df_full. If so, check what value to add into df_combined for ALDH1 inhibition.
# If a molecule from df_inhibition is NOT found in df_full, it is added to the list
# "molecule_not_found".
for molecule in list(df_inhibition["SMILES"]):
    if molecule in all_molecules:
        index = df_inhibition[df_inhibition["SMILES"] == molecule].index[0]
        if df_inhibition["ALDH1_inhibition"][index] == 1:
            df_combined.loc[209, molecule] = "Yes"
        else:
            df_combined.loc[209, molecule] = "No"
    else:
        molecule_not_found.append(molecule)

# Variable name "ALDH1_inhibition" is added to df_combined.
df_combined.loc[209, "0"] = "ALDH1_inhibition"

# Finally check for what molecules the ALDH1 inhibition is known. All molecules for which 
# this is unknown are removed from df_combined.
for molecule in df_full.columns:
    if (molecule not in select_molecules) & (molecule != "0"):
        df_combined = df_combined.drop([molecule], axis=1)

# %% [markdown]
# <p>Check how many molecules from df_inhibition were not found in df_full.<p>

# %%
not_found = len(molecule_not_found)
assert not_found == 0, f"{not_found} molecule(s) from df_inhibition was/were not in df_full."

# %% [markdown]
# <h2>Transpose df_combined and exprot it as csv</h2>

# %%
df_transposed = df_full.transpose()
df_transposed.to_csv("Nearly_useful_sheet.csv")

# %% [markdown]
# <h3><em>After the "Nearly_useful_sheet.csv" has been saved, it has to be slightly edited <br>
#         so that it is more practical to use for further purposes.<br>
#         Here we might want to edit the csv through a code block also instead of manually.</em></h3>

# %% [markdown]
# <h2>Create DataFrame containing altered version of previously saved csv</h2>

# %% [markdown]
# <p>For the sake of variable analysis, the 2 non-numerical columns are removed.</p>

# %%
DF3 = pd.read_csv("Nearly_Useful_sheet.csv")
DF2 = DF3.loc[:, DF3.columns != "MolecularStructure"]
DF = DF2.loc[:, DF2.columns != "ALDH1_inhibition"]

# %% [markdown]
# <h2>Scale the data using a MinMax scaler to prepare for PCA</h2>

# %%
scaler = MinMaxScaler()
DF[:] = scaler.fit_transform(DF[:])

# %% [markdown]
# <h2>Perform a PCA on DF, so that the given amount data variance (= n_components) is maintained.</h2>

# %%
pca = PCA(n_components = 0.99)
pca.fit(DF)
df_reduced = pd.DataFrame(pca.transform(DF))

# Show snippet of reduced DataFrame.
df_reduced.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.294320  0.061972 -0.381867 -0.215989 -0.419824  0.019302 -0.404613
# 1 -0.594674  0.364144 -0.001158 -0.437065  0.332103  0.153272 -0.260577
# 2 -0.545285  0.540242  0.353119 -0.556473  0.229964 -0.066247 -0.760117
# 3 -0.313512  0.293983  0.376385 -0.534117 -0.085119 -0.498063 -0.411453
# 4 -0.018677  0.205988  0.792597 -0.468045  0.432449  0.421209 -0.377083
#
#         7         8         9    ...       131       132       133       134  \
# 0 -0.414783 -0.231206 -0.067848  ...  0.060683  0.021671 -0.045715  0.014574
# 1 -0.188808  0.713904 -0.450451  ...  0.040493 -0.011957 -0.044447 -0.001647
# 2  0.087230  0.316654 -0.233298  ...  0.071038 -0.031954  0.071361 -0.033829
# 3  0.419518  0.364289 -0.145081  ... -0.096561 -0.034984 -0.036959  0.057146
# 4  0.490808  0.088934 -0.088095  ... -0.052294 -0.043026  0.136110  0.088130
#
#         135       136       137       138       139       140
# 0  0.012738 -0.015213  0.011332 -0.036764 -0.003482  0.072159
# 1 -0.017177  0.001364  0.070869  0.007432  0.059036 -0.066292
# 2  0.094321  0.004247 -0.114699 -0.010909 -0.002995  0.040194
# 3  0.049636 -0.088312 -0.106237  0.034100 -0.025268 -0.043129
# 4 -0.096570  0.009868  0.059854 -0.002838 -0.014372 -0.080889
#
# [5 rows x 141 columns]

# %% [markdown]
# <h2>Re-enter the previously removed columns</h2>

# %%
df_reduced.insert(0, "MolecularStructure", DF3["MolecularStructure"])
# df_reduced.insert(102, "ALDH1_inhibition", DF3["ALDH1_inhibition"])

# Show snippet of final df_reduced.
df_reduced.head()
# Out:
#                                   MolecularStructure         0         1  \
# 0        CCCCC/C(=N\NC(=O)CCC(=O)NCc1ccccc1)c1ccccc1 -0.294320  0.061972
# 1  Cc1ccc(S(=O)(=O)N2CCC(C(=O)OCC(=O)N3CCc4ccccc4... -0.594674  0.364144
# 2  COc1ccc(N2C(=O)CC(Nc3ccc(F)cc3)C2=O)c([N+](=O)... -0.545285  0.540242
# 3  Cc1cc(C)cc(OCC(=O)O[NH+]=C(N)Cc2ccc([N+](=O)[O... -0.313512  0.293983
# 4            NNC(=O)C=C1CCN(c2ncc(C(F)(F)F)cc2Cl)CC1 -0.018677  0.205988
#
#           2         3         4         5         6         7         8  ...  \
# 0 -0.381867 -0.215989 -0.419824  0.019302 -0.404613 -0.414783 -0.231206  ...
# 1 -0.001158 -0.437065  0.332103  0.153272 -0.260577 -0.188808  0.713904  ...
# 2  0.353119 -0.556473  0.229964 -0.066247 -0.760117  0.087230  0.316654  ...
# 3  0.376385 -0.534117 -0.085119 -0.498063 -0.411453  0.419518  0.364289  ...
# 4  0.792597 -0.468045  0.432449  0.421209 -0.377083  0.490808  0.088934  ...
#
#         131       132       133       134       135       136       137  \
# 0  0.060683  0.021671 -0.045715  0.014574  0.012738 -0.015213  0.011332
# 1  0.040493 -0.011957 -0.044447 -0.001647 -0.017177  0.001364  0.070869
# 2  0.071038 -0.031954  0.071361 -0.033829  0.094321  0.004247 -0.114699
# 3 -0.096561 -0.034984 -0.036959  0.057146  0.049636 -0.088312 -0.106237
# 4 -0.052294 -0.043026  0.136110  0.088130 -0.096570  0.009868  0.059854
#
#         138       139       140
# 0 -0.036764 -0.003482  0.072159
# 1  0.007432  0.059036 -0.066292
# 2 -0.010909 -0.002995  0.040194
# 3  0.034100 -0.025268 -0.043129
# 4 -0.002838 -0.014372 -0.080889
#
# [5 rows x 142 columns]

# %% [markdown]
# <h2>Export the final df_reduced as csv for further use</h2>

# %%
df_reduced.to_csv("reduced_scaled_list_of_unknown_molecs.csv")
